# %% [markdown]
# # Instrucciones
#
#  * Descargar el archivo de Excel llamado “Datos.xls” ubicado en la sección de "Bienvenida" del curso.
#
# * Leer atentamente las preguntas.
#
# * Realizar cálculos, desarrollos y análisis en base al archivo.
#
# * Las respuestas que debes seleccionar están asociadas a los códigos o resultados que obtendrás del trabajo con el archivo.

# %%
# import library to work with dataframes
import pandas as pd

# %%
# load excel file
df_hospitales = pd.read_excel("../data/03_Datos.xls", sheet_name="Hospitales")

# %%
df_hospitales.head()
# Out:
#                             Nombre Servicio de Salud  \
# 0  Metropolitano Norte                           ...
# 1  Metropolitano Occidente                       ...
# 2  Metropolitano Occidente                       ...
# 3  Metropolitano Occidente                       ...
# 4  Metropolitano Occidente                       ...
#
#                          Nombre Establecimiento  \
# 0                Complejo Hospitalario San José
# 1        Hospital Adalberto Steeger (Talagante)
# 2               Hospital Dr. Félix Bulnes Cerda
# 3                     Hospital San Juan de Dios
# 4  Instituto Traumatológico Dr. Teodoro Gebauer
#
#    Área Cuidados Intensivos Adultos  Área Cuidados Intermedios Adulto  \
# 0                                11                                33
# 1                                 6                                11
# 2                                 3                                 6
# ...

# %% [markdown]
# 1 ¿Cuál de las siguientes opciones corresponde al código que permite calcular el total de camas críticas para cada uno de los servicios de salud?

# %%
df_hospitales[["Nombre Servicio de Salud", "Total Camas Críticas"]].groupby("Nombre Servicio de Salud").sum()
# Out:
#                                                     Total Camas Críticas
# Nombre Servicio de Salud
# Metropolitano Central                                                105
# Metropolitano Norte                                                   44
# Metropolitano Occidente                                              120
# Metropolitano Oriente                                                137
# Metropolitano Sur                                                    173
# Metropolitano Sur Oriente                                            127

# %% [markdown]
# 2.¿Cuáles de los siguientes servicios de salud son los tres servicios que tienen más camas críticas?
#
# Selecciona las tres respuestas que consideres correctas.

# %%
df_hospitales[["Nombre Servicio de Salud", "Total Camas Críticas"]].groupby("Nombre Servicio de Salud").sum().sort_values(by="Total Camas Críticas", ascending=False)
# Out:
#                                                     Total Camas Críticas
# Nombre Servicio de Salud
# Metropolitano Sur                                                    173
# Metropolitano Oriente                                                137
# Metropolitano Sur Oriente                                            127
# Metropolitano Occidente                                              120
# Metropolitano Central                                                105
# Metropolitano Norte                                                   44

# %%
df_hospitales[["Nombre Servicio de Salud", "Total Camas Críticas"]].groupby("Nombre Servicio de Salud").sum().nlargest(3, "Total Camas Críticas")
# Out:
#                                                     Total Camas Críticas
# Nombre Servicio de Salud
# Metropolitano Sur                                                    173
# Metropolitano Oriente                                                137
# Metropolitano Sur Oriente                                            127

# %% [markdown]
# 3.¿Cuál de los siguientes códigos permite calcular el costo promedio diario de atención para el GRD4?

# %%
df_hospitales["Costo diario GRD4 [MM$]"].mean()
# Out:
# np.float64(0.4484761904761904)

# %%
#Load other tab
df_info = pd.read_excel("../data/03_Datos.xls", sheet_name="Información Histórica")

# %%
df_info.head()
# Out:
#    Número de llegada                         Hospital al que llega    GRD  \
# 0                  1  Instituto Traumatológico Dr. Teodoro Gebauer   GRD3
# 1                  2           Hospital Clínico San Borja-Arriarán   GRD7
# 2                  3                    Hospital Dr. Luis Tisné B.   GRD7
# 3                  4         Hospital Dr. Exequiel González Cortés  GRD10
# 4                  5                  Hospital Barros Luco Trudeau   GRD6
#
#    Día de llegada  Día de salida  Estadia
# 0               1              4        3
# 1               1              5        4
# 2               1              5        4
# 3               1             11       10
# 4               1              6        5

# %%
df_info = df_info.drop("Hospital al que llega", axis=1)

# %%
data = df_info[(df_info["Día de llegada"] >= 415) & (df_info["Día de llegada"] <= 424)]

# %%
df_info.head()
# Out:
#    Número de llegada    GRD  Día de llegada  Día de salida  Estadia
# 0                  1   GRD3               1              4        3
# 1                  2   GRD7               1              5        4
# 2                  3   GRD7               1              5        4
# 3                  4  GRD10               1             11       10
# 4                  5   GRD6               1              6        5

# %% [markdown]
# 5. ¿Cuál de las siguientes alternativas indica el promedio del costo diario de resolución de los 3 GRDs más costos en clínica privada?

# %%
df_grd = pd.read_excel("../data/03_Datos.xls", sheet_name="GRD")
df_grd.head()
# Out:
#   ID GRD    Nombre GRD  Costo resolución en Clínica Privada [MM$]
# 0   GRD1     Coronario                                      7.917
# 1   GRD2      Hepático                                      3.417
# 2   GRD3  Respiratorio                                      2.915
# 3   GRD4         Renal                                      6.188
# 4   GRD5   Neurológico                                      6.782

# %%
df_largest =  df_grd.nlargest(3, "Costo resolución en Clínica Privada [MM$]")

# %%
df_largest["Costo resolución en Clínica Privada [MM$]"].mean()
# Out:
# np.float64(7.538333333333334)

# %% [markdown]
# 7. ¿Cuál de las siguientes alternativas corresponde a la diferencia entre el menor y el mayor costo de operación anual de una cama crítica en el sistema de salud (considerando todos los servicios de salud)?

# %%
df_hospitales.head()
# Out:
#                             Nombre Servicio de Salud  \
# 0  Metropolitano Norte                           ...
# 1  Metropolitano Occidente                       ...
# 2  Metropolitano Occidente                       ...
# 3  Metropolitano Occidente                       ...
# 4  Metropolitano Occidente                       ...
#
#                          Nombre Establecimiento  \
# 0                Complejo Hospitalario San José
# 1        Hospital Adalberto Steeger (Talagante)
# 2               Hospital Dr. Félix Bulnes Cerda
# 3                     Hospital San Juan de Dios
# 4  Instituto Traumatológico Dr. Teodoro Gebauer
#
#    Área Cuidados Intensivos Adultos  Área Cuidados Intermedios Adulto  \
# 0                                11                                33
# 1                                 6                                11
# 2                                 3                                 6
# ...

# %%
df_hospitales["Costo de operación anual de una cama [MM$]"].max()
# Out:
# np.float64(66.1)

# %%
df_hospitales["Costo de operación anual de una cama [MM$]"].min()
# Out:
# np.float64(36.6)

# %%
df_hospitales["Costo de operación anual de una cama [MM$]"].max() - df_hospitales["Costo de operación anual de una cama [MM$]"].min()
# Out:
# np.float64(29.499999999999993)

# %% [markdown]
# 8. ¿Cuál de las siguientes alternativas indica la cantidad de pacientes que llegaron a la red de salud el día en que llegaron más pacientes?

# %%
df_info.groupby("Día de llegada").size().sort_values(ascending=False).nlargest(1)
# Out:
# Día de llegada
# 420    183
# dtype: int64

# %% [markdown]
# 9. ¿Cuál de las siguientes alternativas corresponde al código que permite determinar el promedio del total de camas críticas de cada servicio de salud de la red?

# %%
df_hospitales[["Nombre Servicio de Salud", "Total Camas Críticas"]].groupby("Nombre Servicio de Salud").mean()
# Out:
#                                                     Total Camas Críticas
# Nombre Servicio de Salud
# Metropolitano Central                                              35.00
# Metropolitano Norte                                                44.00
# Metropolitano Occidente                                            30.00
# Metropolitano Oriente                                              34.25
# Metropolitano Sur                                                  34.60
# Metropolitano Sur Oriente                                          31.75

# %% [markdown]
# 10. ¿Cuál de las siguientes alternativas corresponde al código para determinar el costo de instalar las 3 camas nuevas menos costosas en cada servicio de salud?

# %%
df_hospitales[["Nombre Servicio de Salud", "Costo de instalar una cama [MM$]"]].groupby("Nombre Servicio de Salud").min() * 3
# Out:
#                                                     Costo de instalar una cama [MM$]
# Nombre Servicio de Salud
# Metropolitano Central                                                           3768
# Metropolitano Norte                                                             4221
# Metropolitano Occidente                                                         3198
# Metropolitano Oriente                                                           3168
# Metropolitano Sur                                                               3153
# Metropolitano Sur Oriente                                                       3084

# %%
costo_camas = df_hospitales[[
    "Nombre Servicio de Salud", "Costo de instalar una cama [MM$]"
]].groupby("Nombre Servicio de Salud").min()
costo_camas
# Out:
#                                                     Costo de instalar una cama [MM$]
# Nombre Servicio de Salud
# Metropolitano Central                                                           1256
# Metropolitano Norte                                                             1407
# Metropolitano Occidente                                                         1066
# Metropolitano Oriente                                                           1056
# Metropolitano Sur                                                               1051
# Metropolitano Sur Oriente                                                       1028

# %%
costo_camas["costo 3 camas nuevas"] = costo_camas["Costo de instalar una cama [MM$]"] * 3

# %%
costo_camas
# Out:
#                                                     Costo de instalar una cama [MM$]  \
# Nombre Servicio de Salud
# Metropolitano Central                                                           1256
# Metropolitano Norte                                                             1407
# Metropolitano Occidente                                                         1066
# Metropolitano Oriente                                                           1056
# Metropolitano Sur                                                               1051
# Metropolitano Sur Oriente                                                       1028
#
#                                                     costo 3 camas nuevas
# Nombre Servicio de Salud
# Metropolitano Central                                               3768
# Metropolitano Norte                                                 4221
# Metropolitano Occidente                                             3198
# ...

# %% [markdown]
# # Quiz

# %% [markdown]
# ¿Cuál de las siguientes alternativas indica correctamente el promedio de camas de cuidados intensivos adultos existentes en el Servicio de Salud Metropolitano?

# %%
df_hospitales.head()
# Out:
#                             Nombre Servicio de Salud  \
# 0  Metropolitano Norte                           ...
# 1  Metropolitano Occidente                       ...
# 2  Metropolitano Occidente                       ...
# 3  Metropolitano Occidente                       ...
# 4  Metropolitano Occidente                       ...
#
#                          Nombre Establecimiento  \
# 0                Complejo Hospitalario San José
# 1        Hospital Adalberto Steeger (Talagante)
# 2               Hospital Dr. Félix Bulnes Cerda
# 3                     Hospital San Juan de Dios
# 4  Instituto Traumatológico Dr. Teodoro Gebauer
#
#    Área Cuidados Intensivos Adultos  Área Cuidados Intermedios Adulto  \
# 0                                11                                33
# 1                                 6                                11
# 2                                 3                                 6
# ...

# %%
df_hospitales["Área Cuidados Intensivos Adultos"].mean()
# Out:
# np.float64(14.047619047619047)

# %%
df_hospitales.columns
# Out:
# Index(['Nombre Servicio de Salud', 'Nombre Establecimiento',
#        'Área Cuidados Intensivos Adultos', 'Área Cuidados Intermedios Adulto',
#        'Total Camas Críticas', 'Máxima cantidad de camas a aumetar',
#        'Costo de instalar una cama [MM$]',
#        'Costo de operación anual de una cama [MM$]', 'Costo diario GRD1 [MM$]',
#        'Costo diario GRD2 [MM$]', 'Costo diario GRD3 [MM$]',
#        'Costo diario GRD4 [MM$]', 'Costo diario GRD5 [MM$]',
#        'Costo diario GRD6 [MM$]', 'Costo diario GRD7 [MM$]',
#        'Costo diario GRD8 [MM$]', 'Costo diario GRD9 [MM$]',
#        'Costo diario GRD10 [MM$]'],
#       dtype='object')

# %% [markdown]
# ¿Cuál de las siguientes alternativas indica correctamente el costo máximo diario de atención en el Servicio de Salud Metropolitano?

# %%
df_hospitales[['Costo diario GRD1 [MM$]',
       'Costo diario GRD2 [MM$]', 'Costo diario GRD3 [MM$]',
       'Costo diario GRD4 [MM$]', 'Costo diario GRD5 [MM$]',
       'Costo diario GRD6 [MM$]', 'Costo diario GRD7 [MM$]',
       'Costo diario GRD8 [MM$]', 'Costo diario GRD9 [MM$]',
       'Costo diario GRD10 [MM$]']].max().max()
# Out:
# np.float64(0.599)

# %%
df_hospitales[['Costo diario GRD1 [MM$]',
       'Costo diario GRD2 [MM$]', 'Costo diario GRD3 [MM$]',
       'Costo diario GRD4 [MM$]', 'Costo diario GRD5 [MM$]',
       'Costo diario GRD6 [MM$]', 'Costo diario GRD7 [MM$]',
       'Costo diario GRD8 [MM$]', 'Costo diario GRD9 [MM$]',
       'Costo diario GRD10 [MM$]']].min().min()
# Out:
# np.float64(0.302)

# %% [markdown]
# Utilizando Dataframe y comandos de Python, indique ¿cuál de las siguientes alternativas indica correctamente el máximo de camas críticas que hay en total en los Servicios de Salud Metropolitano Sur y Sur Oriente?

# %%
df_hospitales.columns
# Out:
# Index(['Nombre Servicio de Salud', 'Nombre Establecimiento',
#        'Área Cuidados Intensivos Adultos', 'Área Cuidados Intermedios Adulto',
#        'Total Camas Críticas', 'Máxima cantidad de camas a aumetar',
#        'Costo de instalar una cama [MM$]',
#        'Costo de operación anual de una cama [MM$]', 'Costo diario GRD1 [MM$]',
#        'Costo diario GRD2 [MM$]', 'Costo diario GRD3 [MM$]',
#        'Costo diario GRD4 [MM$]', 'Costo diario GRD5 [MM$]',
#        'Costo diario GRD6 [MM$]', 'Costo diario GRD7 [MM$]',
#        'Costo diario GRD8 [MM$]', 'Costo diario GRD9 [MM$]',
#        'Costo diario GRD10 [MM$]'],
#       dtype='object')

# %%
df_hospitales[["Nombre Servicio de Salud", "Total Camas Críticas"]].groupby("Nombre Servicio de Salud").max().sort_values(by="Total Camas Críticas", ascending=False)
# Out:
#                                                     Total Camas Críticas
# Nombre Servicio de Salud
# Metropolitano Occidente                                               76
# Metropolitano Sur                                                     74
# Metropolitano Sur Oriente                                             55
# Metropolitano Oriente                                                 46
# Metropolitano Central                                                 44
# Metropolitano Norte                                                   44

# %% [markdown]
# How to export data in csv

# %%
df_grd.to_csv(path_or_buf="../data/processed/grd.csv", index=False, encoding="utf-8")

# %%
df_hospitales.to_csv(path_or_buf="../data/processed/hospitales.csv", index=False, encoding="utf-8")

# %%
df_info.to_csv(path_or_buf="../data/processed/info.csv", index=False, encoding="utf-8")

# %% [markdown]
# Utilizando el Dataframe Estadía_promedio_Excel.xlsx y comandos de Python, ¿cuál de las siguientes alternativas corresponde a la máxima estadía promedio de entre los GRDs?

# %%
df_info[["GRD", "Estadia"]].groupby("GRD").max().max()
# Out:
# Estadia    10
# dtype: int64

# %% [markdown]
# Utilizando el archivo “Datos.xls”, un Dataframe y comandos en Python, ¿cuál de las siguientes alternativas corresponde al costo total de instalar el máximo de camas críticas posibles en toda la región?

# %%
df_hospitales["Costo total aumento camas"] = df_hospitales["Máxima cantidad de camas a aumetar"] * df_hospitales["Costo de instalar una cama [MM$]"]

# %%
df_hospitales["Costo total aumento camas"].sum()
# Out:
# np.int64(240509)

# %% [markdown]
# Primero, utilice el archivo datos punto XLS. Segundo, construya un data frame que indique la cantidad de camas que tiene el hospital con mayor capacidad. Luego, guarda esta información en un archivo excel llamado "MaxCamasCC x SS"
#
# ### # Error, quiere decir servicio de salud y no hospitales, esta lleno de errores de redacccion este curso

# %%
df_hospitales_exported = df_hospitales[["Nombre Servicio de Salud", "Total Camas Críticas"]].groupby("Nombre Servicio de Salud").max()

# %%
df_hospitales_exported.to_excel(excel_writer="../data/processed/MaxCamasCCxSS.xlsx")

# %% [markdown]
# construya un gráfico y una tabla de frecuencias de la cantidad de pacientes que llegan diariamente al sistema de salud.

# %%
df_info.columns
# Out:
# Index(['Número de llegada', 'Hospital al que llega', 'GRD', 'Día de llegada',
#        'Día de salida', 'Estadia'],
#       dtype='object')

# %%
df_info.head()
# Out:
#    Número de llegada                         Hospital al que llega    GRD  \
# 0                  1  Instituto Traumatológico Dr. Teodoro Gebauer   GRD3
# 1                  2           Hospital Clínico San Borja-Arriarán   GRD7
# 2                  3                    Hospital Dr. Luis Tisné B.   GRD7
# 3                  4         Hospital Dr. Exequiel González Cortés  GRD10
# 4                  5                  Hospital Barros Luco Trudeau   GRD6
#
#    Día de llegada  Día de salida  Estadia
# 0               1              4        3
# 1               1              5        4
# 2               1              5        4
# 3               1             11       10
# 4               1              6        5

# %%
df_info["recount"] = 1

# %%
df_info
# Out:
#        Número de llegada                              Hospital al que llega  \
# 0                      1       Instituto Traumatológico Dr. Teodoro Gebauer
# 1                      2                Hospital Clínico San Borja-Arriarán
# 2                      3                         Hospital Dr. Luis Tisné B.
# 3                      4              Hospital Dr. Exequiel González Cortés
# 4                      5                       Hospital Barros Luco Trudeau
# ...                  ...                                                ...
# 65529              65530                Hospital Clínico San Borja-Arriarán
# 65530              65531              Hospital Dr. Exequiel González Cortés
# 65531              65532                              Hospital Del Salvador
# 65532              65533  Hospital de Enfermedades Infecciosas Dr. Lucio...
# 65533              65534  Hospital de Urgencia Asistencia Pública Dr. Al...
#
# ...

# %%
df_info[["Día de llegada", "recount"]].groupby("Día de llegada").count()
# Out:
#                 recount
# Día de llegada
# 1                   146
# 2                   142
# 3                   152
# 4                   156
# 5                   152
# ...                 ...
# 420                 183
# 421                 159
# 422                 160
# 423                 159
# 424                  82
#
# [424 rows x 1 columns]

# %%
df_info_filtered = df_info[["Día de llegada", "recount"]].groupby("Día de llegada").count()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_info_filtered.plot(
    kind="hist",
    alpha=0.7,
    bins=30,
    rot=45,
    title="Frecuencia Paciente",
    xlabel="Dia llegada",
    ylabel="Frecuencia",
    figsize=(10,5),
    fontsize=15,
    color=["#A0E8Af", "#FFCF56"]
)
plt.show()

# %% [markdown]
# construir un diagrama de caja que indique o que muestre el costo promedio de instalar una "Cama crítica" en cada "Servicio de salud" de la red.
#
# ### Otro error, ese diagrama no muetsra el costo promedio, si no la mediana en la linea de al medio de la caja

# %%
df_hospitales.head()
# Out:
#                             Nombre Servicio de Salud  \
# 0  Metropolitano Norte                           ...
# 1  Metropolitano Occidente                       ...
# 2  Metropolitano Occidente                       ...
# 3  Metropolitano Occidente                       ...
# 4  Metropolitano Occidente                       ...
#
#                          Nombre Establecimiento  \
# 0                Complejo Hospitalario San José
# 1        Hospital Adalberto Steeger (Talagante)
# 2               Hospital Dr. Félix Bulnes Cerda
# 3                     Hospital San Juan de Dios
# 4  Instituto Traumatológico Dr. Teodoro Gebauer
#
#    Área Cuidados Intensivos Adultos  Área Cuidados Intermedios Adulto  \
# 0                                11                                33
# 1                                 6                                11
# 2                                 3                                 6
# ...

# %%
df_hospitales.boxplot(
    column=["Costo de instalar una cama [MM$]"],
    by="Nombre Servicio de Salud",
    figsize=(15,9),
    fontsize=8,
)
plt.title("Costo x camas por servicio")

plt.show()

# %% [markdown]
# # Evaluacion 2

# %% [markdown]
# Instrucciones
#
# Descargar el archivo de Excel llamado “Datos.xls”  ubicado en la sección de "Bienvenida" del curso.
#
# Leer atentamente las preguntas.
#
# Realizar cálculos, desarrollos y análisis en base al archivo.
#
# Las respuestas que debes seleccionar están asociadas a los códigos o resultados que obtendrás del trabajo con el archivo.

# %% [markdown]
# 1. ¿Cuál opción corresponde al servicio de salud al que llegaron más pacientes el día 1?

# %%
df_info.head()
# Out:
#    Número de llegada                         Hospital al que llega    GRD  \
# 0                  1  Instituto Traumatológico Dr. Teodoro Gebauer   GRD3
# 1                  2           Hospital Clínico San Borja-Arriarán   GRD7
# 2                  3                    Hospital Dr. Luis Tisné B.   GRD7
# 3                  4         Hospital Dr. Exequiel González Cortés  GRD10
# 4                  5                  Hospital Barros Luco Trudeau   GRD6
#
#    Día de llegada  Día de salida  Estadia  recount
# 0               1              4        3        1
# 1               1              5        4        1
# 2               1              5        4        1
# 3               1             11       10        1
# 4               1              6        5        1

# %%
df_info[["Hospital al que llega", "Día de llegada"]]
# Out:
#                                    Hospital al que llega  Día de llegada
# 0           Instituto Traumatológico Dr. Teodoro Gebauer               1
# 1                    Hospital Clínico San Borja-Arriarán               1
# 2                             Hospital Dr. Luis Tisné B.               1
# 3                  Hospital Dr. Exequiel González Cortés               1
# 4                           Hospital Barros Luco Trudeau               1
# ...                                                  ...             ...
# 65529                Hospital Clínico San Borja-Arriarán             424
# 65530              Hospital Dr. Exequiel González Cortés             424
# 65531                              Hospital Del Salvador             424
# 65532  Hospital de Enfermedades Infecciosas Dr. Lucio...             424
# 65533  Hospital de Urgencia Asistencia Pública Dr. Al...             424
#
# [65534 rows x 2 columns]

# %%
df_info_filtered = df_info[df_info["Día de llegada"] == 1].groupby("Hospital al que llega").sum()[["Día de llegada"]]

# %%
df_info_filtered
# Out:
#                                                     Día de llegada
# Hospital al que llega
# Complejo Hospitalario Dr. Sótero del Río                        10
# Complejo Hospitalario San José                                  16
# Hospital Adalberto Steeger (Talagante)                           4
# Hospital Barros Luco Trudeau                                    14
# Hospital Clínico San Borja-Arriarán                             14
# Hospital Clínico de la Florida                                   1
# Hospital Del Salvador                                           11
# Hospital Dr. Exequiel González Cortés                            7
# Hospital Dr. Félix Bulnes Cerda                                 10
# Hospital Dr. Luis Tisné B.                                      13
# Hospital El Pino                                                 2
# Hospital Metropolitano ( ex Militar )                            1
# Hospital Padre Alberto Hurtado (San Ramón)                       2
# ...

# %%
df_hospitales_filtered = df_hospitales[["Nombre Establecimiento", "Nombre Servicio de Salud"]]

# %%
df_hospitales_filtered.head()
# Out:
#                          Nombre Establecimiento  \
# 0                Complejo Hospitalario San José
# 1        Hospital Adalberto Steeger (Talagante)
# 2               Hospital Dr. Félix Bulnes Cerda
# 3                     Hospital San Juan de Dios
# 4  Instituto Traumatológico Dr. Teodoro Gebauer
#
#                             Nombre Servicio de Salud
# 0  Metropolitano Norte                           ...
# 1  Metropolitano Occidente                       ...
# 2  Metropolitano Occidente                       ...
# 3  Metropolitano Occidente                       ...
# 4  Metropolitano Occidente                       ...

# %%
df_final = df_info_filtered.merge(
    df_hospitales_filtered, 
    left_on="Hospital al que llega", 
    right_on="Nombre Establecimiento", 
    how="inner"
)
df_final
# Out:
#     Día de llegada                             Nombre Establecimiento  \
# 0               10         Complejo Hospitalario Dr. Sótero del Río
# 1               16                     Complejo Hospitalario San José
# 2                4             Hospital Adalberto Steeger (Talagante)
# 3               14                       Hospital Barros Luco Trudeau
# 4               14                Hospital Clínico San Borja-Arriarán
# 5                1                     Hospital Clínico de la Florida
# 6               11                              Hospital Del Salvador
# 7                7              Hospital Dr. Exequiel González Cortés
# 8               10                    Hospital Dr. Félix Bulnes Cerda
# 9               13                         Hospital Dr. Luis Tisné B.
# 10               2                                   Hospital El Pino
# 11               1              Hospital Metropolitano ( ex Militar )
# ...

# %%
df_final.groupby("Nombre Servicio de Salud").sum().sort_values(by="Día de llegada",ascending=False)
# Out:
#                                                     Día de llegada  \
# Nombre Servicio de Salud
# Metropolitano Oriente                                           36
# Metropolitano Occidente                                         29
# Metropolitano Sur                                               26
# Metropolitano Central                                           25
# Metropolitano Norte                                             16
# Metropolitano Sur Oriente                                       14
#
#                                                                                Nombre Establecimiento
# Nombre Servicio de Salud
# Metropolitano Oriente                               Hospital Del SalvadorHospital Dr. Luis Tisné B...
# Metropolitano Occidente                             Hospital Adalberto Steeger (Talagante)Hospital...
# Metropolitano Sur                                   Hospital Barros Luco TrudeauHospital Dr. Exequ...
# ...

# %% [markdown]
# 2. ¿Cuál de las siguientes alternativas corresponde a la cantidad total de pacientes de los GRDs 1, 7 y 10 que han llegado al servicio de salud Metropolitano Sur? (considere la historia total disponible)

# %%
df_info.head()
# Out:
#    Número de llegada                         Hospital al que llega    GRD  \
# 0                  1  Instituto Traumatológico Dr. Teodoro Gebauer   GRD3
# 1                  2           Hospital Clínico San Borja-Arriarán   GRD7
# 2                  3                    Hospital Dr. Luis Tisné B.   GRD7
# 3                  4         Hospital Dr. Exequiel González Cortés  GRD10
# 4                  5                  Hospital Barros Luco Trudeau   GRD6
#
#    Día de llegada  Día de salida  Estadia  recount
# 0               1              4        3        1
# 1               1              5        4        1
# 2               1              5        4        1
# 3               1             11       10        1
# 4               1              6        5        1

# %%
df_final = df_info.merge(
    df_hospitales_filtered, 
    left_on="Hospital al que llega", 
    right_on="Nombre Establecimiento", 
    how="inner"
)
df_final
# Out:
#        Número de llegada                              Hospital al que llega  \
# 0                      1       Instituto Traumatológico Dr. Teodoro Gebauer
# 1                      2                Hospital Clínico San Borja-Arriarán
# 2                      3                         Hospital Dr. Luis Tisné B.
# 3                      4              Hospital Dr. Exequiel González Cortés
# 4                      5                       Hospital Barros Luco Trudeau
# ...                  ...                                                ...
# 65529              65530                Hospital Clínico San Borja-Arriarán
# 65530              65531              Hospital Dr. Exequiel González Cortés
# 65531              65532                              Hospital Del Salvador
# 65532              65533  Hospital de Enfermedades Infecciosas Dr. Lucio...
# 65533              65534  Hospital de Urgencia Asistencia Pública Dr. Al...
#
# ...

# %%
df_final[(df_final['GRD'].isin(['GRD1', 'GRD7', 'GRD10']))]
# Out:
#        Número de llegada                              Hospital al que llega  \
# 1                      2                Hospital Clínico San Borja-Arriarán
# 2                      3                         Hospital Dr. Luis Tisné B.
# 3                      4              Hospital Dr. Exequiel González Cortés
# 5                      6  Instituto Nacional de Enfermedades Respiratori...
# 7                      8                         Hospital Dr. Luis Tisné B.
# ...                  ...                                                ...
# 65514              65515  Instituto Nacional de Enfermedades Respiratori...
# 65520              65521                       Hospital Barros Luco Trudeau
# 65524              65525                     Hospital Clínico de la Florida
# 65531              65532                              Hospital Del Salvador
# 65533              65534  Hospital de Urgencia Asistencia Pública Dr. Al...
#
# ...

# %%
df_final["Nombre Servicio de Salud"]=='Metropolitano Sur                                 '
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 65529    False
# 65530     True
# 65531    False
# 65532     True
# 65533    False
# Name: Nombre Servicio de Salud, Length: 65534, dtype: bool

# %%
df_final[
    (df_final['GRD'].isin(['GRD1', 'GRD7', 'GRD10'])) & 
    (df_final["Nombre Servicio de Salud"]=='Metropolitano Sur                                 ')
][["Nombre Servicio de Salud", "recount", "GRD"]].groupby("GRD").sum().sort_values(by="GRD", ascending=True)
# Out:
#                                 Nombre Servicio de Salud  recount
# GRD
# GRD1   Metropolitano Sur                             ...     1311
# GRD10  Metropolitano Sur                             ...     1269
# GRD7   Metropolitano Sur                             ...     1293
